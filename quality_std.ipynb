# %%
from PIL import Image
import numpy as np
import os
from random import shuffle
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
DIR = './VizWiz_quality_issues/img/'
df = pd.read_csv('./VizWiz_quality_issues/annotations.csv')
img_name = df.iloc[:,0].tolist()

# %%
# Want to know how we should format the height x width image data dimensions
# for inputting to a keras model
def get_size_statistics():
    heights = []
    widths = []
    img_count = 0
    for img in os.listdir(DIR):
        path = os.path.join(DIR, img)
        if "DS_Store" not in path:
            data = np.array(Image.open(path))
            heights.append(data.shape[0])
            widths.append(data.shape[1])
            img_count += 1
    avg_height = sum(heights) / len(heights)
    avg_width = sum(widths) / len(widths)
    print("Average Height: " + str(avg_height))
    print("Max Height: " + str(max(heights)))
    print("Min Height: " + str(min(heights)))
    print('\n')
    print("Average Width: " + str(avg_width))
    print("Max Width: " + str(max(widths)))
    print("Min Width: " + str(min(widths)))

get_size_statistics()
# Out:
# Average Height: 1362.626126126126
# Max Height: 1936
# Min Height: 21
#
#
# Average Width: 1110.6463963963963
# Max Width: 2592
# Min Width: 16

# %%
def label_img(name):
    print (name)
    index = img_name.index(name)
    y_temp = df.iloc[index,1:9]
    data_y = y_temp.values
    #print (data_y)
    return (data_y)
    #return (np.array([0, 1]))

# %%
IMG_SIZE = 300

def load_training_data():
    train_data = []
    for img in os.listdir(DIR):
        label = label_img(img)
        path = os.path.join(DIR, img)
        if "DS_Store" not in path:
            img = Image.open(path)
            img = img.convert('L')
            img = img.resize((IMG_SIZE, IMG_SIZE), Image.ANTIALIAS)
            train_data.append([np.array(img), label])
            
    shuffle(train_data)
    print(train_data)
    return train_data

# %%
train_data = load_training_data()
plt.imshow(train_data[3][0], cmap = 'gist_gray')
# Out:
# VizWiz_test_000000021805.jpg
# VizWiz_train_000000009744.jpg
# VizWiz_train_000000002177.jpg
# VizWiz_train_000000018675.jpg
# VizWiz_train_000000009977.jpg
# VizWiz_val_000000029608.jpg
# VizWiz_train_000000000562.jpg
# VizWiz_train_000000002413.jpg
# VizWiz_train_000000004062.jpg
# VizWiz_train_000000008658.jpg
# VizWiz_train_000000008102.jpg
# VizWiz_test_000000025849.jpg
# VizWiz_test_000000020070.jpg
# VizWiz_test_000000021408.jpg
# VizWiz_train_000000017618.jpg
# VizWiz_train_000000011527.jpg
# VizWiz_train_000000015966.jpg
# VizWiz_train_000000002598.jpg
# VizWiz_test_000000021795.jpg
# VizWiz_train_000000009181.jpg
# VizWiz_val_000000030946.jpg
# VizWiz_test_000000027469.jpg
# VizWiz_train_000000007190.jpg
# VizWiz_test_000000027440.jpg
# VizWiz_train_000000018927.jpg
# VizWiz_train_000000005976.jpg
# VizWiz_test_000000020313.jpg
# VizWiz_train_000000005989.jpg
# VizWiz_train_000000017341.jpg
# VizWiz_test_000000020139.jpg
# VizWiz_train_000000006099.jpg
# ...

# %%
trainImages_x = np.array([i[0] for i in train_data]).reshape(-1, IMG_SIZE, IMG_SIZE, 1)
trainLabels_y = np.array([i[1] for i in train_data])

# %%
# Reshape X_train and X_test into 2D array so that it can be standardized using standard scaler
dataset_size = len(trainImages_x)
trainImages_x2D = trainImages_x.reshape(dataset_size,-1)

# %%
# Split the dataset
X_train, X_test, y_train, y_test = train_test_split(trainImages_x2D, trainLabels_y, test_size=0.2, random_state=42 )

# %%
X_test.shape
# Out:
# (178, 90000)

# %%
# Fit standard scaler to the training dataset
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
std_scaler = scaler.fit(X_train)
# Out:
# /Users/jasleen/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype uint8 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
# Transform the training dataset
X_train_std = std_scaler.transform(X_train)
# Out:
# /Users/jasleen/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype uint8 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
X_train_std.shape
# Out:
# (710, 90000)

# %%
# Transform the test dataset
X_test_std = std_scaler.transform(X_test)
# Out:
# /Users/jasleen/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:595: DataConversionWarning: Data with input dtype uint8 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.layers. normalization import BatchNormalization
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
# Reshape the data to fit the model
X_train_std1 = X_train_std.reshape(-1, IMG_SIZE, IMG_SIZE, 1)

# %%
X_train_std1.shape
# Out:
# (710, 300, 300, 1)

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size = (3, 3), activation='relu', input_shape=(IMG_SIZE, IMG_SIZE,1)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())
model.add(Conv2D(64, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())
model.add(Conv2D(96, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())
model.add(Conv2D(96, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())
model.add(Conv2D(64, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())
model.add(Dropout(0.2))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(128, activation='relu'))
#model.add(Dropout(0.3))
model.add(Dense(8, activation = 'softmax'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics = ['accuracy'])

# %%
model.fit(X_train_std1, y_train, batch_size = 50, epochs = 5, verbose = 1)
# Out:
# WARNING:tensorflow:From /Users/jasleen/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/5
# 710/710 [==============================] - 77s 108ms/step - loss: 0.5581 - acc: 0.7796
# Epoch 2/5
# 710/710 [==============================] - 71s 100ms/step - loss: 0.4725 - acc: 0.7968
# Epoch 3/5
# 710/710 [==============================] - 71s 100ms/step - loss: 0.4374 - acc: 0.7995
# Epoch 4/5
# 710/710 [==============================] - 71s 99ms/step - loss: 0.3854 - acc: 0.8171
# Epoch 5/5
# 710/710 [==============================] - 71s 100ms/step - loss: 0.3542 - acc: 0.8268

# %%
# Reshape the test dataset
X_test_std1 = X_test_std.reshape(-1, IMG_SIZE, IMG_SIZE, 1)

# %%
# Accuracy on test data
loss, acc = model.evaluate(X_test_std1, y_test, verbose = 0)
print(acc * 100)
# Out:
# 80.47752795594462

# %% [markdown]
# # Experiment 2

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size = (3, 3), activation='relu', input_shape=(IMG_SIZE, IMG_SIZE, 1)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())

model.add(Conv2D(64, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())

model.add(Conv2D(96, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())

model.add(Conv2D(96, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())

model.add(Conv2D(64, kernel_size=(3,3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(BatchNormalization())

model.add(Conv2D(32, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(BatchNormalization())

model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(8, activation = 'softmax'))

# %%
model.compile(loss='binary_crossentropy', optimizer='rmsprop', metrics = ['accuracy'])

# %%
model.fit(X_train_std1, y_train, batch_size = 50, epochs = 7, verbose = 1)
# Out:
# Epoch 1/7
# 710/710 [==============================] - 71s 100ms/step - loss: 0.5568 - acc: 0.7732
# Epoch 2/7
# 710/710 [==============================] - 72s 101ms/step - loss: 0.5071 - acc: 0.7734
# Epoch 3/7
# 710/710 [==============================] - 70s 99ms/step - loss: 0.5010 - acc: 0.7722
# Epoch 4/7
# 710/710 [==============================] - 71s 100ms/step - loss: 0.4934 - acc: 0.7738
# Epoch 5/7
# 710/710 [==============================] - 69s 97ms/step - loss: 0.4831 - acc: 0.7738
# Epoch 6/7
# 710/710 [==============================] - 67s 94ms/step - loss: 0.4835 - acc: 0.7773
# Epoch 7/7
# 710/710 [==============================] - 67s 94ms/step - loss: 0.4762 - acc: 0.7732

# %%
# Accuracy on train data
loss, acc = model.evaluate(X_train_std1, y_train, verbose = 0)
print(acc * 100)
# Out:
# 78.2570422367311

# %%
# Accuracy on test data
loss, acc = model.evaluate(X_test_std1, y_test, verbose = 0)
print(acc * 100)
# Out:
# 78.23033694470867
